# %% [markdown]
# # Generate Stochastic Volatility Surface Samples
#
# This notebook generates samples for the future training of models to fit volatilities implied from Stochastic Volatility model parameters.
#
# ToDo:
# * Run one generation
# * Find out how to retrieve files
# * Check how long we can run without being interrupted by Colab

# %%
# Import relevant modules
import os
import numpy as np
from platform import python_version

# Install and import SDevPy modules
# !pip install sdevpy --upgrade
import sdevpy as sd
from sdevpy.tools.timer import Stopwatch
from sdevpy.tools import filemanager
from sdevpy.volsurfacegen import stovolfactory

print("Python version: " + python_version())
print("NumPy version: " + np.__version__)
print("SDevPy version: " + sd.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sdevpy in /usr/local/lib/python3.10/dist-packages (0.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from sdevpy) (1.5.3)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.10/dist-packages (from sdevpy) (1.8.2)
# Requirement already satisfied: py-vollib in /usr/local/lib/python3.10/dist-packages (from sdevpy) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->sdevpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->sdevpy) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->sdevpy) (1.22.4)
# Requirement already satisfied: py-lets-be-rational in /usr/local/lib/python3.10/dist-packages (from py-vollib->sdevpy) (1.0.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from py-vollib->sdevpy) (3.19.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from py-vollib->sdevpy) (1.10.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->sdevpy) (1.16.0)
# Python version: 3.10.12
# NumPy version: 1.22.4
# SDevPy version: 1.0.0

# %% [markdown]
# ## 1) Set runtime configuration

# %%
# Global settings
# MODEL_TYPE = "ShiftedSABR"
# MODEL_TYPE = "McShiftedSABR"
MODEL_TYPE = "FbSABR"
# MODEL_TYPE = "McShiftedZABR"
# MODEL_TYPE = "McShiftedHeston"
NUM_SAMPLES = 10 * 1000
NUM_EXPIRIES = 10
SURFACE_SIZE = 50
# The 2 parameters below are only relevant for models whose reference is calculated by MC
NUM_MC = 100 * 1000 # 100 * 1000
POINTS_PER_YEAR = 25 # 25
# Change seed to generate different sets
SEED = 12# [2468, 8642, 2112, 4444, 88, 6666, 1122, 12]

print(">> Set up runtime configuration")
project_folder = "/content/sdevpy/stovol"
# !mkdir -p sdevpy/stovol
# !unzip -u "/content/sdev.python-pinns_worst_of.zip" -d sdev.python/models
print("> Project folder: " + project_folder)
data_folder = os.path.join(project_folder, "samples")
print("> Data folder: " + data_folder)
filemanager.check_directory(data_folder)
print("> Chosen model: " + MODEL_TYPE)
data_file = os.path.join(data_folder, MODEL_TYPE + "_samples.tsv")
# Out:
# >> Set up runtime configuration
# > Project folder: /content/sdevpy/stovol
# > Data folder: /content/sdevpy/stovol/samples
# > Chosen model: FbSABR

# %% [markdown]
# ## 2) Generate samples
#
# Here we generate the samples using the SDevPy framework. First prices are calculated with the chosen models. Then these prices are transformed into normal volatilities and the data is cleansed. Finally a tsv file is output containing the dataset.

# %%
# Select the model
generator = stovolfactory.set_generator(MODEL_TYPE, NUM_EXPIRIES, SURFACE_SIZE, NUM_MC,
                                        POINTS_PER_YEAR, SEED)

# %%
# Generate samples (prices)
print(f"> Generate {NUM_SAMPLES:,} price samples")
timer_gen = Stopwatch("Generating Samples")
timer_gen.trigger()
data_df = generator.generate_samples(NUM_SAMPLES)
timer_gen.stop()

# Convert to normal vols and cleanse
print("> Convert to normal vol and cleanse data")
timer_conv = Stopwatch("Converting Prices")
timer_conv.trigger()
data_df = generator.to_nvol(data_df, cleanse=True)
num_clean = len(data_df.index)
print(f"> Dataset size after cleansing: {num_clean:,}")
timer_conv.stop()

# Output to file
timer_out = Stopwatch("File Output")
timer_out.trigger()
generator.to_file(data_df, data_file)
timer_out.stop()

# View timers
timer_gen.print()
timer_conv.print()
timer_out.print()
# Out:
# > Generate 10,000 price samples
# Number of strikes: 5
# Number of expiries: 10
# Surface size: 50
# Number of samples: 10,000
# Number of surfaces/parameter samples: 200
# Surface generation number 1/200
# Surface generation number 2/200
# Surface generation number 3/200
# Surface generation number 4/200
# Surface generation number 5/200
# Surface generation number 6/200
# Surface generation number 7/200
# Surface generation number 8/200
# Surface generation number 9/200
# Surface generation number 10/200
# Surface generation number 11/200
# Surface generation number 12/200
# Surface generation number 13/200
# Surface generation number 14/200
# Surface generation number 15/200
# Surface generation number 16/200
# Surface generation number 17/200
# Surface generation number 18/200
# Surface generation number 19/200
# Surface generation number 20/200
# Surface generation number 21/200
# Surface generation number 22/200
# Surface generation number 23/200
# Surface generation number 24/200
# Surface generation number 25/200
# Surface generation number 26/200
# Surface generation number 27/200
# Surface generation number 28/200
# Surface generation number 29/200
# Surface generation number 30/200
# Surface generation number 31/200
# Surface generation number 32/200
# Surface generation number 33/200
# Surface generation number 34/200
# Surface generation number 35/200
# Surface generation number 36/200
# Surface generation number 37/200
# Surface generation number 38/200
# Surface generation number 39/200
# Surface generation number 40/200
# Surface generation number 41/200
# Surface generation number 42/200
# Surface generation number 43/200
# Surface generation number 44/200
# Surface generation number 45/200
# Surface generation number 46/200
# Surface generation number 47/200
# Surface generation number 48/200
# Surface generation number 49/200
# Surface generation number 50/200
# Surface generation number 51/200
# Surface generation number 52/200
# Surface generation number 53/200
# Surface generation number 54/200
# Surface generation number 55/200
# Surface generation number 56/200
# Surface generation number 57/200
# Surface generation number 58/200
# Surface generation number 59/200
# Surface generation number 60/200
# Surface generation number 61/200
# Surface generation number 62/200
# Surface generation number 63/200
# Surface generation number 64/200
# Surface generation number 65/200
# Surface generation number 66/200
# Surface generation number 67/200
# Surface generation number 68/200
# Surface generation number 69/200
# Surface generation number 70/200
# Surface generation number 71/200
# Surface generation number 72/200
# Surface generation number 73/200
# Surface generation number 74/200
# Surface generation number 75/200
# Surface generation number 76/200
# Surface generation number 77/200
# Surface generation number 78/200
# Surface generation number 79/200
# Surface generation number 80/200
# Surface generation number 81/200
# Surface generation number 82/200
# Surface generation number 83/200
# Surface generation number 84/200
# Surface generation number 85/200
# Surface generation number 86/200
# Surface generation number 87/200
# Surface generation number 88/200
# Surface generation number 89/200
# Surface generation number 90/200
# Surface generation number 91/200
# Surface generation number 92/200
# Surface generation number 93/200
# Surface generation number 94/200
# Surface generation number 95/200
# Surface generation number 96/200
# Surface generation number 97/200
# Surface generation number 98/200
# Surface generation number 99/200
# Surface generation number 100/200
# Surface generation number 101/200
# Surface generation number 102/200
# Surface generation number 103/200
# Surface generation number 104/200
# Surface generation number 105/200
# Surface generation number 106/200
# Surface generation number 107/200
# Surface generation number 108/200
# Surface generation number 109/200
# Surface generation number 110/200
# Surface generation number 111/200
# Surface generation number 112/200
# Surface generation number 113/200
# Surface generation number 114/200
# Surface generation number 115/200
# Surface generation number 116/200
# Surface generation number 117/200
# Surface generation number 118/200
# Surface generation number 119/200
# Surface generation number 120/200
# Surface generation number 121/200
# Surface generation number 122/200
# Surface generation number 123/200
# Surface generation number 124/200
# Surface generation number 125/200
# Surface generation number 126/200
# Surface generation number 127/200
# Surface generation number 128/200
# Surface generation number 129/200
# Surface generation number 130/200
# Surface generation number 131/200
# Surface generation number 132/200
# Surface generation number 133/200
# Surface generation number 134/200
# Surface generation number 135/200
# Surface generation number 136/200
# Surface generation number 137/200
# Surface generation number 138/200
# Surface generation number 139/200
# Surface generation number 140/200
# Surface generation number 141/200
# Surface generation number 142/200
# Surface generation number 143/200
# Surface generation number 144/200
# Surface generation number 145/200
# Surface generation number 146/200
# Surface generation number 147/200
# Surface generation number 148/200
# Surface generation number 149/200
# Surface generation number 150/200
# Surface generation number 151/200
# Surface generation number 152/200
# Surface generation number 153/200
# Surface generation number 154/200
# Surface generation number 155/200
# Surface generation number 156/200
# Surface generation number 157/200
# Surface generation number 158/200
# Surface generation number 159/200
# Surface generation number 160/200
# Surface generation number 161/200
# Surface generation number 162/200
# Surface generation number 163/200
# Surface generation number 164/200
# Surface generation number 165/200
# Surface generation number 166/200
# Surface generation number 167/200
# Surface generation number 168/200
# Surface generation number 169/200
# Surface generation number 170/200
# Surface generation number 171/200
# Surface generation number 172/200
# Surface generation number 173/200
# Surface generation number 174/200
# Surface generation number 175/200
# Surface generation number 176/200
# Surface generation number 177/200
# Surface generation number 178/200
# Surface generation number 179/200
# Surface generation number 180/200
# Surface generation number 181/200
# Surface generation number 182/200
# Surface generation number 183/200
# Surface generation number 184/200
# Surface generation number 185/200
# Surface generation number 186/200
# Surface generation number 187/200
# Surface generation number 188/200
# Surface generation number 189/200
# Surface generation number 190/200
# Surface generation number 191/200
# Surface generation number 192/200
# Surface generation number 193/200
# Surface generation number 194/200
# Surface generation number 195/200
# Surface generation number 196/200
# Surface generation number 197/200
# Surface generation number 198/200
# Surface generation number 199/200
# Surface generation number 200/200
# > Convert to normal vol and cleanse data
# Converting to normal vol, batch 1 out of 2
# > Dataset size after cleansing: 7,334
# Runtime(Generating Samples): 5199.3s
# Runtime(Converting Prices): 5.1s
# Runtime(File Output): 0.2s
